# %%
from scipy.sparse import *

rating_matrix_csc = load_npz('netflix/sparse_matrix_100%.npz').tocsc()
print("file load DONE")
# Out:
# file load DONE

# %%
a = rating_matrix_csc[:,0:int(rating_matrix_csc.shape[1]*0.75)].getnnz(axis=0).tolist()
a.sort()

# %%
import numpy as np
import matplotlib.pyplot as plt

n, bins, patches = plt.hist(np.array(a[0:]), 1000, facecolor='g',cumulative=False, alpha=0.75)

plt.xlabel('number of ratings')
plt.ylabel('number of items')
plt.title('distribution of rating')
plt.axis([25000, 35000, 0, 50])
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n, bins, patches = plt.hist(np.array(a[:]),2000, facecolor='b',cumulative=False, alpha=0.75)

plt.xlabel('number of ratings')
plt.ylabel('number of users')
plt.title('distribution of rating')
plt.axis([0, 100, 0, 10000])
plt.grid(True)
plt.show()

# %%
a.sort()
plt.plot(a[0:10])
plt.show()

# %%
# Out:
# '2017-11-09 00:49:17'
