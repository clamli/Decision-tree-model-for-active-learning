# %% [markdown]
# ## Package

# %%
import numpy as np
from copy import deepcopy
from matrix_factorization import MatrixFactorization
import pandas as pd
import scipy.sparse
from scipy import *
import tool_function as tf

# %% [markdown]
# ## FDTree Class

# %%
import numpy as np
from scipy.sparse import find
from copy import deepcopy
from matrix_factorization import MatrixFactorization

class DecisionTreeModel:
    def __init__(self, sMatrix, depth_threshold=6, plambda=7, MSP_item=200):
        '''
            sMatrix: I*U matrix
            depth_threshold: terminate depth
            plambda: regularization parameter
            self.rI: dict { 
                        itemid1: [ [uid11, rating11], [uid12, rating12], ... ] rating for item 1
                        itemid2: [ [uid21, rating21], [uid22, rating22], ... ] rating for item 2
                        itemid3: ...
                     }
            self.rU: dict {
                        userid1: { itemid11: rating11, itemid12: rating12, ... } rating of user 1
                        userid2: { itemid21: rating21, itemid22: rating22, ... } rating of user 2
                        userid3: ...
                     }
            self.lr_bound: dict {
                                level 0: [[left_bound, right_bound]], users' bound for one level, each ele in dictionary represents one node
                                level 1: [[left_bound, right_bound], [left_bound, right_bound], [left_bound, right_bound]], 3
                                level 2: ..., 9
                            } (bound means index)
            self.tree: []  all of userid
            self.split_item: list [
                    level 0: []
                    level 1: []
                    level 2: []
            ]
            self.sum_cur_t: dict {
                        itemid1: {'rating': sum of ratings for item 1, 'cnt': sum of users rated item 1}
                        itemid2: {'rating': sum of ratings for item 2, 'cnt': sum of users rated item 2}
                        ...
                    }
            self.sum_2_cur_t: dict {
                        itemid1: sum of square ratings for item 1
                        itemid2: sum of square ratings for item 2
                        ...
                    }
            self.biasU: dict {
                        userid1: bias1
                        userid2: bias2
                        ...
                    }
            self.user_profile: dict {
                        level 0: {pseudo_user1: [k1, k2, k3, ... , kt]}
                        level 1: {pseudo_user1: [k1, k2, k3, ... , kt], pseudo_user2: [k1, k2, k3, ... , kt], pseudo_user3: [k1, k2, k3, ... , kt]}
                        ... 
                    } profile for each level's node
            self.item_profile: dict {
                        level 0: [[k1, k2, k3, ... , kt], [k1, k2, k3, ... , kt], [k1, k2, k3, ... , kt], ...] for each item
                        level 1: [[k1, k2, k3, ... , kt], [k1, k2, k3, ... , kt], [k1, k2, k3, ... , kt], ...] for each item
                        ...
                    } profile for each item
            every element represents ratings for one item, its order decide the users in tree nodes
        '''
        self.depth_threshold = depth_threshold
        self.plambda = plambda
        self.cur_depth = 0
        self.MSP_item = MSP_item
        self.real_item_num = sMatrix.shape[0]
        x = find(sMatrix)
        itemset = x[0]
        userset = x[1]	
        # self.rI = {}
        self.rU = {}	
        self.sum_cur_t = {}
        self.sum_2_cur_t = {}
        # self.rI[itemset[0]] = [[userset[0], sMatrix[itemset[0], userset[0]]]]
        # self.rU[userset[0]] = {itemset[0]: sMatrix[itemset[0], userset[0]]}
        self.global_mean = 0                   # global average of ratings

        #### Calculate rate of progress ####
        self.node_num = 0
        self.cur_node = 0
        for i in range(self.depth_threshold):
            self.node_num += 3**i

        #### Generate rI, rU ####
        self.rI = list(set(sMatrix.nonzero()[0]))
        for itemid, userid in zip(itemset, userset):
            self.rU.setdefault(userid, {})[itemid] = sMatrix[itemid, userid]
            # self.rI.setdefault(itemid, []).append([userid, sMatrix[itemid, userid]])
            self.global_mean += sMatrix[itemid, userid]
        self.global_mean /= len(itemset)
        self.item_size = len(self.rI)
        self.user_size = len(self.rU)

        #### Initiate Tree, lr_bound ####
        self.tree = list(self.rU.keys())
        self.split_item = []
        self.lr_bound = {'0': [[0, len(self.tree)-1]]}

        #### Generate bias, sum_cur_t, sum_2_cur_t ####
        self.biasU = {}
        self.sum_cur_t = np.zeros(self.real_item_num)
        self.sum_2_cur_t = np.zeros(self.real_item_num)
        self.sum_cntt = np.zeros(self.real_item_num)
#         self.sum_cur_t[itemset[0]] = {'rating': sMatrix[itemset[0], userset[0]]-self.biasU[userset[0]], 'cnt': 1}
#         self.sum_2_cur_t[itemset[0]] = (sMatrix[itemset[0], userset[0]]-self.biasU[userset[0]])**2
        for userid in self.rU:
            self.biasU[userid] = (sum(list(self.rU[userid].values())) + self.plambda*self.global_mean) / (self.plambda + len(self.rU[userid]))
            user_all_rating_id = np.array(list(self.rU[userid].keys()))
            # print('user_all_rating_id ', user_all_rating_id[:])
            user_all_rating = np.array(list(self.rU[userid].values()))
            self.sum_cur_t[user_all_rating_id[:]] += user_all_rating[:] - self.biasU[userid]
            self.sum_2_cur_t[user_all_rating_id[:]] += (user_all_rating[:] - self.biasU[userid])**2
            self.sum_cntt[user_all_rating_id[:]] += 1
        
#         for itemid, userid, ind in zip(itemset[1:],userset[1:],range(1, len(itemset))):
#             if itemid == itemset[ind-1]:
#                 self.sum_cur_t[itemid]['rating'] += sMatrix[itemid, userid]-self.biasU[userid]
#                 self.sum_cur_t[itemid]['cnt'] += 1
#                 self.sum_2_cur_t[itemid] += (sMatrix[itemid, userid]-self.biasU[userid])**2
#             else:
#                 self.sum_cur_t[itemid] = {'rating': sMatrix[itemid, userid]-self.biasU[userid], 'cnt': 1}
#                 self.sum_2_cur_t[itemid] = (sMatrix[itemid, userid]-self.biasU[userid])**2

        #### Prediction Model ####
        self.user_profile = {}
        self.item_profile = {}
        self.MF = MatrixFactorization()

        print("Initiation DONE!")


    def calculate_error(self, sumt, sumt_2, cntt):
        ''' Calculate error for one item-split in one node '''
        Error_i = np.sum(sumt_2 - (sumt**2)/(cntt+1e-9))
#         for itemid in sumtL:
#             Error_i += sumtL_2[itemid] - (sumtL[itemid]['rating']**2)/(sumtL[itemid]['cnt']+1e-9) \
#                         + sumtD_2[itemid] - (sumtD[itemid]['rating']**2)/(sumtD[itemid]['cnt']+1e-9) \
#                             + sumtU_2[itemid] - (sumtU[itemid]['rating']**2)/(sumtU[itemid]['cnt']+1e-9)
        return Error_i


    def generate_decision_tree(self, lr_bound_for_node, chosen_id):
        '''
            sumtL: dict {
                itemid1: {'rating': sum of ratings for item 1, 'cnt': sum of users rated item 1}
                itemid2: {'rating': sum of ratings for item 2, 'cnt': sum of users rated item 2}
                ...
            }
            sumtL_2: dict {
                itemid1: sum of square ratings for item 1
                itemid2: sum of square ratings for item 2
                ...
            }
            lr_bound_for_node: list [leftind, rightind] for one node
        '''

        #### Terminate ####
        self.cur_depth += 1
        if self.cur_depth > self.depth_threshold or len(chosen_id) == self.item_size:
            return
        
        #### Choose Most Popular Items of This Node ####
        num_rec = np.zeros(self.real_item_num)      
        for userid in self.tree[lr_bound_for_node[0]:(lr_bound_for_node[1]+1)]:
            user_all_rating_id = np.array(list(self.rU[userid].keys()))
            num_rec[user_all_rating_id[:]] += 1
        sub_item_id = np.argsort(num_rec)[:self.MSP_item]
        

        #### Find optimum item to split ####
        min_sumtL, min_sumtD, min_sumtL_2, min_sumtD_2, min_sumtU, min_sumtU_2, Error = {}, {}, {}, {}, {}, {}, {}
        min_Error = "None"
        for itemid in sub_item_id:
            if itemid in chosen_id:
                continue
            ''' 
                user_rating_item_in_nodet: [ [uid01, rating01], [uid02, rating02], ... ] 
                to find all users in node t who rates item i
            '''
            user_rating_item_in_nodet = ([userid, self.rU[userid][itemid]] for userid in self.tree[lr_bound_for_node[0]:(lr_bound_for_node[1]+1)] if itemid in self.rU[userid])
            sumt = np.zeros((self.real_item_num, 3))
            sumt_2 = np.zeros((self.real_item_num, 3))
            cntt = np.zeros((self.real_item_num, 3))
            for user in user_rating_item_in_nodet:
                ''' user_all_rating: array [ [itemid11, rating11], [itemid12, rating12], ... ] '''
                user_all_rating_id = np.array(list(self.rU[user[0]].keys()))
                user_all_rating = np.array(list(self.rU[user[0]].values()))
                #### calculate sumtL for node LIKE ####
                if user[1] >= 4:
                    sumt[user_all_rating_id[:], 0] += user_all_rating[:] - self.biasU[user[0]]
                    sumt_2[user_all_rating_id[:], 0] += (user_all_rating[:] - self.biasU[user[0]])**2
                    cntt[user_all_rating_id[:], 0] += 1
                #### calculate sumtD for node DISLIKE ####
                elif user[1] <= 3:
                    sumt[user_all_rating_id[:], 1] += user_all_rating[:] - self.biasU[user[0]]
                    sumt_2[user_all_rating_id[:], 1] += (user_all_rating[:] - self.biasU[user[0]])**2
                    cntt[user_all_rating_id[:], 1] += 1
            #### calculate sumtU for node UNKNOWN ####
            sumt[:, 2] = self.sum_cur_t[:] - sumt[:, 0] - sumt[:, 1]
            sumt_2[:, 2] = self.sum_2_cur_t[:] - sumt_2[:, 0] - sumt_2[:, 1]
            cntt[:, 2] = self.sum_cntt[:] - cntt[:, 0] - cntt[:, 1]
            Error[itemid] = self.calculate_error(sumt, sumt_2, cntt)            
                
                
#             sumtL, sumtD, sumtL_2, sumtD_2, sumtU, sumtU_2 = {}, {}, {}, {}, {}, {}
#             sumtL = {k:{'rating': 0, 'cnt': 0} for k in self.rI.keys()}
#             sumtL_2 = sumtL_2.fromkeys(self.rI.keys(), 0)
#             sumtD = {k:{'rating': 0, 'cnt': 0} for k in self.rI.keys()}
#             sumtD_2 = sumtD_2.fromkeys(self.rI.keys(), 0)
#             for user in user_rating_item_in_nodet:
#                 ''' user_all_rating: [ [itemid11, rating11], [itemid12, rating12], ... ] '''
#                 user_all_rating = self.rU[user[0]]
#                 #### calculate sumtL for node LIKE ####
#                 if user[1] >= 4:
#                     for uritem, rating in user_all_rating.items():
#                         sumtL[uritem]['rating'] += rating
#                         sumtL_2[uritem] += (rating-self.biasU[user[0]])**2
#                         sumtL[uritem]['rating'] -= self.biasU[user[0]]
#                         sumtL[uritem]['cnt'] += 1
#                 #### calculate sumtD for node DISLIKE ####
#                 elif user[1] <= 3:
#                     for uritem, rating in user_all_rating.items():
#                         sumtD[uritem]['rating'] += rating
#                         sumtD_2[uritem] += (rating-self.biasU[user[0]])**2
#                         sumtD[uritem]['rating'] -= self.biasU[user[0]]
#                         sumtD[uritem]['cnt'] += 1
#             #### calculate sumtU for node UNKNOWN ####
#             for iid in self.rI:
#                 sumtU[iid] = {}
#                 sumtU[iid]['rating'] = self.sum_cur_t[iid]['rating'] - sumtL[iid]['rating'] - sumtD[iid]['rating']
#                 sumtU[iid]['cnt'] = self.sum_cur_t[iid]['cnt'] - sumtL[iid]['cnt'] - sumtD[iid]['cnt']
#                 sumtU_2[iid] = self.sum_2_cur_t[iid] - sumtL_2[iid] - sumtD_2[iid]
#             #### calculate error by (eL + eD + eU) ####
#             Error[itemid] = self.calculate_error(sumtL, sumtL_2, sumtD, sumtD_2, sumtU, sumtU_2)
            if min_Error == "None" or Error[itemid] < min_Error:
                min_sumt = sumt
                min_sumt_2 = sumt_2
                min_cntt = cntt
                min_Error = Error[itemid]
        #### Find optimum split-item ####
        optimum_itemid = min(Error, key=Error.get)
        if len(self.split_item) == self.cur_depth-1:
            self.split_item.append([optimum_itemid])
        else:
            self.split_item[self.cur_depth-1].append(optimum_itemid)
        # self.split_item.setdefault(str(self.cur_depth-1), []).append(optimum_itemid)
        chosen_id.append(optimum_itemid)


        #### sort tree ####
        self.lr_bound.setdefault(str(self.cur_depth), []).append([])                                          # for LIKE
        self.lr_bound[str(self.cur_depth)].append([])   					                                  # for DISLIKE
        self.lr_bound[str(self.cur_depth)].append([])                                    					  # for UNKNOWN
        listU, listL, listD = [], [], []
        for userid in self.tree[lr_bound_for_node[0]:(lr_bound_for_node[1]+1)]:
            if optimum_itemid not in self.rU[userid]:
                listU.append(userid)
            elif self.rU[userid][optimum_itemid] >= 4:
                listL.append(userid)
            elif self.rU[userid][optimum_itemid] <= 3:
                listD.append(userid)
        self.tree[lr_bound_for_node[0]:(lr_bound_for_node[1]+1)] = listL + listD + listU
        self.lr_bound[str(self.cur_depth)][-3] = [lr_bound_for_node[0], lr_bound_for_node[0]+len(listL)-1]                                                     # for LIKE
        self.lr_bound[str(self.cur_depth)][-2] = [lr_bound_for_node[0]+len(listL), lr_bound_for_node[0]+len(listL)+len(listD)-1]                                 # for DISLIKE
        self.lr_bound[str(self.cur_depth)][-1] = [lr_bound_for_node[0]+len(listL)+len(listD), lr_bound_for_node[0]+len(listL)+len(listD)+len(listU)-1]           # for UNKNOWN


        #### Generate Subtree of Node LIKE ####
        self.sum_cur_t = min_sumt[:, 0]
        self.sum_2_cur_t = min_sumt_2[:, 0]
        self.sum_cntt = min_cntt[:, 0]
        self.generate_decision_tree(self.lr_bound[str(self.cur_depth)][-3], chosen_id[:])    
        self.cur_depth -= 1

        #### Generate Subtree of Node DISLIKE ####
        self.sum_cur_t = min_sumt[:, 1]
        self.sum_2_cur_t = min_sumt_2[:, 1]
        self.sum_cntt = min_cntt[:, 1]
        self.generate_decision_tree(self.lr_bound[str(self.cur_depth)][-2], chosen_id[:])    
        self.cur_depth -= 1

        #### Generate Subtree of Node UNKNOWN ####
        self.sum_cur_t = min_sumt[:, 2]
        self.sum_2_cur_t = min_sumt_2[:, 2]
        self.sum_cntt = min_cntt[:, 2]
        self.generate_decision_tree(self.lr_bound[str(self.cur_depth)][-1], chosen_id[:])
        self.cur_depth -= 1

        #### Show Rating Progress ####
        for i in range(self.cur_depth - 1):
            print("┃", end="")        
        print("┏", end="")
        self.cur_node += 1
        print("Current depth: " + str(self.cur_depth) + "        %.2f%%" %(100*self.cur_node/self.node_num))


    def calculate_avg_rating_for_pesudo_user(self, pseudo_user_lst):
        '''ret_dict: dict {
            itemid0: rating0 
            itemid1: rating1
            ...				
        }'''
        cal_dict = {key: {'rating': 0, 'cnt': 0} for key in self.rI}
        ret_dict = {}
        for userid in pseudo_user_lst:
            for itemid, rating in self.rU[userid].items():
                cal_dict[itemid]['rating'] += rating
                cal_dict[itemid]['cnt'] += 1
        for itemid in cal_dict:
            if cal_dict[itemid]['cnt'] == 0:
                continue
            ret_dict[itemid] = cal_dict[itemid]['rating'] / cal_dict[itemid]['cnt']
        return ret_dict


    def generate_prediction_model(self):
        '''self.lr_bound: dict {
                    level 0: [[left_bound, right_bound]], users' bound for one level, each ele in dictionary represents one node
                    level 1: [[left_bound, right_bound], [left_bound, right_bound], [left_bound, right_bound]], 3
                    level 2: ..., 9
                } (bound means index)
        '''
        for level in self.lr_bound:
            self.user_profile.setdefault(level)
            train_lst = []
            for pseudo_user_bound, userid in zip(self.lr_bound[level], range(len(self.lr_bound[level]))):
                if pseudo_user_bound[0] > pseudo_user_bound[1]:
                    continue
                pseudo_user_lst = self.tree[pseudo_user_bound[0]:(pseudo_user_bound[1]+1)]
                pseudo_user_for_item = self.calculate_avg_rating_for_pesudo_user(pseudo_user_lst)
                train_lst += [(userid, int(key), float(value)) for key, value in pseudo_user_for_item.items()]
            self.user_profile[level], self.item_profile[level] = self.MF.matrix_factorization(train_lst)


    def build_model(self):
        #### Construct the tree & get the prediction model ####
        self.generate_decision_tree(self.lr_bound['0'][0], [])
        self.generate_prediction_model()


    def predict(self, new_user_ratings, pred_index):
        ''' new_user_ratings: list [
                       [itemid1, rating1],
                       [itemid2, rating2],
                       [itemid3, rating3],
                       [itemid4, rating4],
                       ... ] 
            pred_rating: array: (I,)
                            new user's rating for each item
         '''

        #### Find user profile for new user ####
        new_user_profile = np.array(self.user_profile[str(len(new_user_ratings))][pred_index])   # shape: (k,)
        new_item_profile = np.array(list(self.item_profile[str(len(new_user_ratings))].values()))               # shape: (I, k)

        #### Calculate predict rating ####
        pred_rating = {itemid: np.dot(new_item_profile[i], new_user_profile) \
            for itemid,i in zip(self.item_profile[str(len(new_user_ratings))], range(new_item_profile.shape[0]))}
        return pred_rating

# %% [markdown]
# ## MF Class

# %%
from pyspark import SparkConf, SparkContext
from pyspark.mllib.recommendation import ALS
from pyspark.sql import SparkSession

class MatrixFactorization:
    def __init__(self, maxIter = 15, regParam = 0.01, rank = 10):
        self.maxIter = maxIter
        self.regParam = regParam  
        self.rank = rank  
        self.spark = SparkSession.builder.master("local[*]").appName("Example").getOrCreate()
        
    def matrix_factorization(self, train_lst):
        
        ratings = self.spark.createDataFrame(train_lst)
        model = ALS.train(ratings, self.rank, seed=10, \
                          iterations = self.maxIter, \
                          lambda_ = self.regParam)
        print("MF DONE")
        userFeatures = sorted(model.userFeatures().collect(), key=lambda d:d[0], reverse = False)
        productFeatures = sorted(model.productFeatures().collect(), key=lambda d:d[0], reverse = False)
        userProfile = {each[0]: each[1].tolist() for each in userFeatures}
        itemProfile = {each[0]: each[1].tolist() for each in productFeatures}
            
        return userProfile, itemProfile

    def end(self):
        self.spark.stop()

# %% [markdown]
# ## Tool Function

# %%
from scipy.sparse import *

def RMSE(real_rating, pred_rating, rated_item):
    rmse, cnt = 0, 0
    for itemid, rating in real_rating.items():
        if itemid not in rated_item:
            rmse += (pred_rating[itemid] - rating)**2
            cnt += 1
    return (rmse/cnt)**0.5

def pred_RMSE_for_new_item(fdtmodel, sM_testing):
    '''
        fdtmodel: FDT class instance
        sM_testing: 30% test dataset (sparse matrix)
        split_item: list [
                level 0: [112], 
                level 1: [48, 0, 79], 
                level 2: [15, 0, 17, 1, 1, 1, 61, 0, 50]
                ...
            ]
        User: dict {
                    userid1: { itemid11: rating11, itemid12: rating12, ... } rating of user 1
                    userid2: { itemid21: rating21, itemid22: rating22, ... } rating of user 2
                    userid3: ...
                }
        return : rmse value (float)
    '''
    x = find(sM_testing)
    itemset = x[0]
    userset = x[1]
    User = {}
    for itemid, userid in zip(itemset, userset):
        if itemid in fdtmodel.rI:
            User.setdefault(userid, {})[itemid] = sM_testing[itemid, userid]

    rmse = 0
    for userid in User:
        pred_index = 0
        new_user_ratings = []
        rated_item = []
        for level in range(len(fdtmodel.split_item)):
            if fdtmodel.split_item[level][pred_index] not in User[userid]:
                tmp_pred_index = 3*pred_index + 2
                if tmp_pred_index in fdtmodel.user_profile[str(int(level)+1)]:
                    new_user_ratings.append([fdtmodel.split_item[level][pred_index], 0])
                    pred_index = tmp_pred_index
                else:
                    break
            elif User[userid][fdtmodel.split_item[level][pred_index]] >= 4:
                tmp_pred_index = 3*pred_index
                if tmp_pred_index in fdtmodel.user_profile[str(int(level)+1)]:
                    rated_item.append(fdtmodel.split_item[level][pred_index])
                    new_user_ratings.append([fdtmodel.split_item[level][pred_index], User[userid][fdtmodel.split_item[level][pred_index]]])
                    pred_index = tmp_pred_index
                else:
                    break
            elif User[userid][fdtmodel.split_item[level][pred_index]] <= 3:
                tmp_pred_index = 3*pred_index + 1
                if tmp_pred_index in fdtmodel.user_profile[str(int(level)+1)]:
                    rated_item.append(fdtmodel.split_item[level][pred_index])
                    new_user_ratings.append([fdtmodel.split_item[level][pred_index], User[userid][fdtmodel.split_item[level][pred_index]]])
                    pred_index = tmp_pred_index
                else:
                    break
        pred_rating = fdtmodel.predict(new_user_ratings, pred_index)
        rmse += RMSE(User[userid], pred_rating, rated_item)

    return rmse / len(User)

# %% [markdown]
# ## Step 1: Input Dataset

# %%
catagory = "Grocery_and_Gourmet_Food"
item_data = 'item_metadata/meta_' + catagory + '.csv'
rating_data = 'user_ratings/' + catagory + '.csv'
# print(rating_data)
ratingsFrame = pd.read_csv(rating_data, names = ["userID", "itemID", "rating"])
ratingsFrame.sort_values(by = 'userID', ascending=True, inplace=True)
itemsFrame = pd.read_csv(item_data)

# %% [markdown]
# ## Step 2: Construct User-Item Sparse Matrix

# %%
item_lst = ratingsFrame["itemID"].tolist()
user_lst = ratingsFrame["userID"].tolist()
rating_lst = ratingsFrame["rating"].tolist()
row = []
col = []
rating_data = []
for i in range(ratingsFrame.shape[0]):
    row.append(item_lst[i])
    col.append(user_lst[i])
    rating_data.append(rating_lst[i])
print(user_lst[len(user_lst)-1])
rating_martix_coo = coo_matrix((rating_data, (row, col)), shape=(itemsFrame.shape[0], user_lst[len(user_lst)-1]+1))
rating_martix_csc = rating_martix_coo.tocsc()
rating_martix_csr = rating_martix_coo.tocsr()
# Out:
# 1748

# %% [markdown]
# ## Step 3: Split dataset into training and test dataset

# %%
start = 0
end = int(rating_martix_csc.shape[1] * 0.7)
sM_training = rating_martix_csc[:, start:end]
sM_testing =  rating_martix_csc[:, end:]

# %% [markdown]
# ## Step 4: Initialize FDT tree and construct prediction model

# %%
dtmodel_realdata = DecisionTreeModel(sM_training, depth_threshold=7)
dtmodel_realdata.build_model()
# Out:
# Initiation DONE!
# ┃┃┃┃┃┃┏Current depth: 7        0.09%
# ┃┃┃┃┃┃┏Current depth: 7        0.18%
# ┃┃┃┃┃┃┏Current depth: 7        0.27%
# ┃┃┃┃┃┏Current depth: 6        0.37%
# ┃┃┃┃┃┃┏Current depth: 7        0.46%
# ┃┃┃┃┃┃┏Current depth: 7        0.55%
# ┃┃┃┃┃┃┏Current depth: 7        0.64%
# ┃┃┃┃┃┏Current depth: 6        0.73%
# ┃┃┃┃┃┃┏Current depth: 7        0.82%
# ┃┃┃┃┃┃┏Current depth: 7        0.91%
# ┃┃┃┃┃┃┏Current depth: 7        1.01%
# ┃┃┃┃┃┏Current depth: 6        1.10%
# ┃┃┃┃┏Current depth: 5        1.19%
# ┃┃┃┃┃┃┏Current depth: 7        1.28%
# ┃┃┃┃┃┃┏Current depth: 7        1.37%
# ┃┃┃┃┃┃┏Current depth: 7        1.46%
# ┃┃┃┃┃┏Current depth: 6        1.56%
# ┃┃┃┃┃┃┏Current depth: 7        1.65%
# ┃┃┃┃┃┃┏Current depth: 7        1.74%
# ┃┃┃┃┃┃┏Current depth: 7        1.83%
# ┃┃┃┃┃┏Current depth: 6        1.92%
# ┃┃┃┃┃┃┏Current depth: 7        2.01%
# ┃┃┃┃┃┃┏Current depth: 7        2.10%
# ┃┃┃┃┃┃┏Current depth: 7        2.20%
# ┃┃┃┃┃┏Current depth: 6        2.29%
# ┃┃┃┃┏Current depth: 5        2.38%
# ┃┃┃┃┃┃┏Current depth: 7        2.47%
# ┃┃┃┃┃┃┏Current depth: 7        2.56%
# ┃┃┃┃┃┃┏Current depth: 7        2.65%
# ┃┃┃┃┃┏Current depth: 6        2.74%
# ┃┃┃┃┃┃┏Current depth: 7        2.84%
# ┃┃┃┃┃┃┏Current depth: 7        2.93%
# ┃┃┃┃┃┃┏Current depth: 7        3.02%
# ┃┃┃┃┃┏Current depth: 6        3.11%
# ┃┃┃┃┃┃┏Current depth: 7        3.20%
# ┃┃┃┃┃┃┏Current depth: 7        3.29%
# ┃┃┃┃┃┃┏Current depth: 7        3.39%
# ┃┃┃┃┃┏Current depth: 6        3.48%
# ┃┃┃┃┏Current depth: 5        3.57%
# ┃┃┃┏Current depth: 4        3.66%
# ┃┃┃┃┃┃┏Current depth: 7        3.75%
# ┃┃┃┃┃┃┏Current depth: 7        3.84%
# ┃┃┃┃┃┃┏Current depth: 7        3.93%
# ┃┃┃┃┃┏Current depth: 6        4.03%
# ┃┃┃┃┃┃┏Current depth: 7        4.12%
# ┃┃┃┃┃┃┏Current depth: 7        4.21%
# ┃┃┃┃┃┃┏Current depth: 7        4.30%
# ┃┃┃┃┃┏Current depth: 6        4.39%
# ┃┃┃┃┃┃┏Current depth: 7        4.48%
# ┃┃┃┃┃┃┏Current depth: 7        4.57%
# ┃┃┃┃┃┃┏Current depth: 7        4.67%
# ┃┃┃┃┃┏Current depth: 6        4.76%
# ┃┃┃┃┏Current depth: 5        4.85%
# ┃┃┃┃┃┃┏Current depth: 7        4.94%
# ┃┃┃┃┃┃┏Current depth: 7        5.03%
# ┃┃┃┃┃┃┏Current depth: 7        5.12%
# ┃┃┃┃┃┏Current depth: 6        5.22%
# ┃┃┃┃┃┃┏Current depth: 7        5.31%
# ┃┃┃┃┃┃┏Current depth: 7        5.40%
# ┃┃┃┃┃┃┏Current depth: 7        5.49%
# ┃┃┃┃┃┏Current depth: 6        5.58%
# ┃┃┃┃┃┃┏Current depth: 7        5.67%
# ┃┃┃┃┃┃┏Current depth: 7        5.76%
# ┃┃┃┃┃┃┏Current depth: 7        5.86%
# ┃┃┃┃┃┏Current depth: 6        5.95%
# ┃┃┃┃┏Current depth: 5        6.04%
# ┃┃┃┃┃┃┏Current depth: 7        6.13%
# ┃┃┃┃┃┃┏Current depth: 7        6.22%
# ┃┃┃┃┃┃┏Current depth: 7        6.31%
# ┃┃┃┃┃┏Current depth: 6        6.40%
# ┃┃┃┃┃┃┏Current depth: 7        6.50%
# ┃┃┃┃┃┃┏Current depth: 7        6.59%
# ┃┃┃┃┃┃┏Current depth: 7        6.68%
# ┃┃┃┃┃┏Current depth: 6        6.77%
# ┃┃┃┃┃┃┏Current depth: 7        6.86%
# ┃┃┃┃┃┃┏Current depth: 7        6.95%
# ┃┃┃┃┃┃┏Current depth: 7        7.04%
# ┃┃┃┃┃┏Current depth: 6        7.14%
# ┃┃┃┃┏Current depth: 5        7.23%
# ┃┃┃┏Current depth: 4        7.32%
# ┃┃┃┃┃┃┏Current depth: 7        7.41%
# ┃┃┃┃┃┃┏Current depth: 7        7.50%
# ┃┃┃┃┃┃┏Current depth: 7        7.59%
# ┃┃┃┃┃┏Current depth: 6        7.69%
# ┃┃┃┃┃┃┏Current depth: 7        7.78%
# ┃┃┃┃┃┃┏Current depth: 7        7.87%
# ┃┃┃┃┃┃┏Current depth: 7        7.96%
# ┃┃┃┃┃┏Current depth: 6        8.05%
# ┃┃┃┃┃┃┏Current depth: 7        8.14%
# ┃┃┃┃┃┃┏Current depth: 7        8.23%
# ┃┃┃┃┃┃┏Current depth: 7        8.33%
# ┃┃┃┃┃┏Current depth: 6        8.42%
# ┃┃┃┃┏Current depth: 5        8.51%
# ┃┃┃┃┃┃┏Current depth: 7        8.60%
# ┃┃┃┃┃┃┏Current depth: 7        8.69%
# ┃┃┃┃┃┃┏Current depth: 7        8.78%
# ┃┃┃┃┃┏Current depth: 6        8.87%
# ┃┃┃┃┃┃┏Current depth: 7        8.97%
# ┃┃┃┃┃┃┏Current depth: 7        9.06%
# ┃┃┃┃┃┃┏Current depth: 7        9.15%
# ┃┃┃┃┃┏Current depth: 6        9.24%
# ┃┃┃┃┃┃┏Current depth: 7        9.33%
# ┃┃┃┃┃┃┏Current depth: 7        9.42%
# ┃┃┃┃┃┃┏Current depth: 7        9.52%
# ┃┃┃┃┃┏Current depth: 6        9.61%
# ┃┃┃┃┏Current depth: 5        9.70%
# ┃┃┃┃┃┃┏Current depth: 7        9.79%
# ┃┃┃┃┃┃┏Current depth: 7        9.88%
# ┃┃┃┃┃┃┏Current depth: 7        9.97%
# ┃┃┃┃┃┏Current depth: 6        10.06%
# ┃┃┃┃┃┃┏Current depth: 7        10.16%
# ┃┃┃┃┃┃┏Current depth: 7        10.25%
# ┃┃┃┃┃┃┏Current depth: 7        10.34%
# ┃┃┃┃┃┏Current depth: 6        10.43%
# ┃┃┃┃┃┃┏Current depth: 7        10.52%
# ┃┃┃┃┃┃┏Current depth: 7        10.61%
# ┃┃┃┃┃┃┏Current depth: 7        10.70%
# ┃┃┃┃┃┏Current depth: 6        10.80%
# ┃┃┃┃┏Current depth: 5        10.89%
# ┃┃┃┏Current depth: 4        10.98%
# ┃┃┏Current depth: 3        11.07%
# ┃┃┃┃┃┃┏Current depth: 7        11.16%
# ┃┃┃┃┃┃┏Current depth: 7        11.25%
# ┃┃┃┃┃┃┏Current depth: 7        11.34%
# ┃┃┃┃┃┏Current depth: 6        11.44%
# ┃┃┃┃┃┃┏Current depth: 7        11.53%
# ┃┃┃┃┃┃┏Current depth: 7        11.62%
# ┃┃┃┃┃┃┏Current depth: 7        11.71%
# ┃┃┃┃┃┏Current depth: 6        11.80%
# ┃┃┃┃┃┃┏Current depth: 7        11.89%
# ┃┃┃┃┃┃┏Current depth: 7        11.99%
# ┃┃┃┃┃┃┏Current depth: 7        12.08%
# ┃┃┃┃┃┏Current depth: 6        12.17%
# ┃┃┃┃┏Current depth: 5        12.26%
# ┃┃┃┃┃┃┏Current depth: 7        12.35%
# ┃┃┃┃┃┃┏Current depth: 7        12.44%
# ┃┃┃┃┃┃┏Current depth: 7        12.53%
# ┃┃┃┃┃┏Current depth: 6        12.63%
# ┃┃┃┃┃┃┏Current depth: 7        12.72%
# ┃┃┃┃┃┃┏Current depth: 7        12.81%
# ┃┃┃┃┃┃┏Current depth: 7        12.90%
# ┃┃┃┃┃┏Current depth: 6        12.99%
# ┃┃┃┃┃┃┏Current depth: 7        13.08%
# ┃┃┃┃┃┃┏Current depth: 7        13.17%
# ┃┃┃┃┃┃┏Current depth: 7        13.27%
# ┃┃┃┃┃┏Current depth: 6        13.36%
# ┃┃┃┃┏Current depth: 5        13.45%
# ┃┃┃┃┃┃┏Current depth: 7        13.54%
# ┃┃┃┃┃┃┏Current depth: 7        13.63%
# ┃┃┃┃┃┃┏Current depth: 7        13.72%
# ┃┃┃┃┃┏Current depth: 6        13.82%
# ┃┃┃┃┃┃┏Current depth: 7        13.91%
# ┃┃┃┃┃┃┏Current depth: 7        14.00%
# ┃┃┃┃┃┃┏Current depth: 7        14.09%
# ┃┃┃┃┃┏Current depth: 6        14.18%
# ┃┃┃┃┃┃┏Current depth: 7        14.27%
# ┃┃┃┃┃┃┏Current depth: 7        14.36%
# ┃┃┃┃┃┃┏Current depth: 7        14.46%
# ┃┃┃┃┃┏Current depth: 6        14.55%
# ┃┃┃┃┏Current depth: 5        14.64%
# ┃┃┃┏Current depth: 4        14.73%
# ┃┃┃┃┃┃┏Current depth: 7        14.82%
# ┃┃┃┃┃┃┏Current depth: 7        14.91%
# ┃┃┃┃┃┃┏Current depth: 7        15.00%
# ┃┃┃┃┃┏Current depth: 6        15.10%
# ┃┃┃┃┃┃┏Current depth: 7        15.19%
# ┃┃┃┃┃┃┏Current depth: 7        15.28%
# ┃┃┃┃┃┃┏Current depth: 7        15.37%
# ┃┃┃┃┃┏Current depth: 6        15.46%
# ┃┃┃┃┃┃┏Current depth: 7        15.55%
# ┃┃┃┃┃┃┏Current depth: 7        15.65%
# ┃┃┃┃┃┃┏Current depth: 7        15.74%
# ┃┃┃┃┃┏Current depth: 6        15.83%
# ┃┃┃┃┏Current depth: 5        15.92%
# ┃┃┃┃┃┃┏Current depth: 7        16.01%
# ┃┃┃┃┃┃┏Current depth: 7        16.10%
# ┃┃┃┃┃┃┏Current depth: 7        16.19%
# ┃┃┃┃┃┏Current depth: 6        16.29%
# ┃┃┃┃┃┃┏Current depth: 7        16.38%
# ┃┃┃┃┃┃┏Current depth: 7        16.47%
# ┃┃┃┃┃┃┏Current depth: 7        16.56%
# ┃┃┃┃┃┏Current depth: 6        16.65%
# ┃┃┃┃┃┃┏Current depth: 7        16.74%
# ┃┃┃┃┃┃┏Current depth: 7        16.83%
# ┃┃┃┃┃┃┏Current depth: 7        16.93%
# ┃┃┃┃┃┏Current depth: 6        17.02%
# ┃┃┃┃┏Current depth: 5        17.11%
# ┃┃┃┃┃┃┏Current depth: 7        17.20%
# ┃┃┃┃┃┃┏Current depth: 7        17.29%
# ┃┃┃┃┃┃┏Current depth: 7        17.38%
# ┃┃┃┃┃┏Current depth: 6        17.47%
# ┃┃┃┃┃┃┏Current depth: 7        17.57%
# ┃┃┃┃┃┃┏Current depth: 7        17.66%
# ┃┃┃┃┃┃┏Current depth: 7        17.75%
# ┃┃┃┃┃┏Current depth: 6        17.84%
# ┃┃┃┃┃┃┏Current depth: 7        17.93%
# ┃┃┃┃┃┃┏Current depth: 7        18.02%
# ┃┃┃┃┃┃┏Current depth: 7        18.12%
# ┃┃┃┃┃┏Current depth: 6        18.21%
# ┃┃┃┃┏Current depth: 5        18.30%
# ┃┃┃┏Current depth: 4        18.39%
# ┃┃┃┃┃┃┏Current depth: 7        18.48%
# ┃┃┃┃┃┃┏Current depth: 7        18.57%
# ┃┃┃┃┃┃┏Current depth: 7        18.66%
# ┃┃┃┃┃┏Current depth: 6        18.76%
# ┃┃┃┃┃┃┏Current depth: 7        18.85%
# ┃┃┃┃┃┃┏Current depth: 7        18.94%
# ┃┃┃┃┃┃┏Current depth: 7        19.03%
# ┃┃┃┃┃┏Current depth: 6        19.12%
# ┃┃┃┃┃┃┏Current depth: 7        19.21%
# ┃┃┃┃┃┃┏Current depth: 7        19.30%
# ┃┃┃┃┃┃┏Current depth: 7        19.40%
# ┃┃┃┃┃┏Current depth: 6        19.49%
# ┃┃┃┃┏Current depth: 5        19.58%
# ┃┃┃┃┃┃┏Current depth: 7        19.67%
# ┃┃┃┃┃┃┏Current depth: 7        19.76%
# ┃┃┃┃┃┃┏Current depth: 7        19.85%
# ┃┃┃┃┃┏Current depth: 6        19.95%
# ┃┃┃┃┃┃┏Current depth: 7        20.04%
# ┃┃┃┃┃┃┏Current depth: 7        20.13%
# ┃┃┃┃┃┃┏Current depth: 7        20.22%
# ┃┃┃┃┃┏Current depth: 6        20.31%
# ┃┃┃┃┃┃┏Current depth: 7        20.40%
# ┃┃┃┃┃┃┏Current depth: 7        20.49%
# ┃┃┃┃┃┃┏Current depth: 7        20.59%
# ┃┃┃┃┃┏Current depth: 6        20.68%
# ┃┃┃┃┏Current depth: 5        20.77%
# ┃┃┃┃┃┃┏Current depth: 7        20.86%
# ┃┃┃┃┃┃┏Current depth: 7        20.95%
# ┃┃┃┃┃┃┏Current depth: 7        21.04%
# ┃┃┃┃┃┏Current depth: 6        21.13%
# ┃┃┃┃┃┃┏Current depth: 7        21.23%
# ┃┃┃┃┃┃┏Current depth: 7        21.32%
# ┃┃┃┃┃┃┏Current depth: 7        21.41%
# ┃┃┃┃┃┏Current depth: 6        21.50%
# ┃┃┃┃┃┃┏Current depth: 7        21.59%
# ┃┃┃┃┃┃┏Current depth: 7        21.68%
# ┃┃┃┃┃┃┏Current depth: 7        21.77%
# ┃┃┃┃┃┏Current depth: 6        21.87%
# ┃┃┃┃┏Current depth: 5        21.96%
# ┃┃┃┏Current depth: 4        22.05%
# ┃┃┏Current depth: 3        22.14%
# ┃┃┃┃┃┃┏Current depth: 7        22.23%
# ┃┃┃┃┃┃┏Current depth: 7        22.32%
# ┃┃┃┃┃┃┏Current depth: 7        22.42%
# ┃┃┃┃┃┏Current depth: 6        22.51%
# ┃┃┃┃┃┃┏Current depth: 7        22.60%
# ┃┃┃┃┃┃┏Current depth: 7        22.69%
# ┃┃┃┃┃┃┏Current depth: 7        22.78%
# ┃┃┃┃┃┏Current depth: 6        22.87%
# ┃┃┃┃┃┃┏Current depth: 7        22.96%
# ┃┃┃┃┃┃┏Current depth: 7        23.06%
# ┃┃┃┃┃┃┏Current depth: 7        23.15%
# ┃┃┃┃┃┏Current depth: 6        23.24%
# ┃┃┃┃┏Current depth: 5        23.33%
# ┃┃┃┃┃┃┏Current depth: 7        23.42%
# ┃┃┃┃┃┃┏Current depth: 7        23.51%
# ┃┃┃┃┃┃┏Current depth: 7        23.60%
# ┃┃┃┃┃┏Current depth: 6        23.70%
# ┃┃┃┃┃┃┏Current depth: 7        23.79%
# ┃┃┃┃┃┃┏Current depth: 7        23.88%
# ┃┃┃┃┃┃┏Current depth: 7        23.97%
# ┃┃┃┃┃┏Current depth: 6        24.06%
# ┃┃┃┃┃┃┏Current depth: 7        24.15%
# ┃┃┃┃┃┃┏Current depth: 7        24.25%
# ┃┃┃┃┃┃┏Current depth: 7        24.34%
# ┃┃┃┃┃┏Current depth: 6        24.43%
# ┃┃┃┃┏Current depth: 5        24.52%
# ┃┃┃┃┃┃┏Current depth: 7        24.61%
# ┃┃┃┃┃┃┏Current depth: 7        24.70%
# ┃┃┃┃┃┃┏Current depth: 7        24.79%
# ┃┃┃┃┃┏Current depth: 6        24.89%
# ┃┃┃┃┃┃┏Current depth: 7        24.98%
# ┃┃┃┃┃┃┏Current depth: 7        25.07%
# ┃┃┃┃┃┃┏Current depth: 7        25.16%
# ┃┃┃┃┃┏Current depth: 6        25.25%
# ┃┃┃┃┃┃┏Current depth: 7        25.34%
# ┃┃┃┃┃┃┏Current depth: 7        25.43%
# ┃┃┃┃┃┃┏Current depth: 7        25.53%
# ┃┃┃┃┃┏Current depth: 6        25.62%
# ┃┃┃┃┏Current depth: 5        25.71%
# ┃┃┃┏Current depth: 4        25.80%
# ┃┃┃┃┃┃┏Current depth: 7        25.89%
# ┃┃┃┃┃┃┏Current depth: 7        25.98%
# ┃┃┃┃┃┃┏Current depth: 7        26.08%
# ┃┃┃┃┃┏Current depth: 6        26.17%
# ┃┃┃┃┃┃┏Current depth: 7        26.26%
# ┃┃┃┃┃┃┏Current depth: 7        26.35%
# ┃┃┃┃┃┃┏Current depth: 7        26.44%
# ┃┃┃┃┃┏Current depth: 6        26.53%
# ┃┃┃┃┃┃┏Current depth: 7        26.62%
# ┃┃┃┃┃┃┏Current depth: 7        26.72%
# ┃┃┃┃┃┃┏Current depth: 7        26.81%
# ┃┃┃┃┃┏Current depth: 6        26.90%
# ┃┃┃┃┏Current depth: 5        26.99%
# ┃┃┃┃┃┃┏Current depth: 7        27.08%
# ┃┃┃┃┃┃┏Current depth: 7        27.17%
# ┃┃┃┃┃┃┏Current depth: 7        27.26%
# ┃┃┃┃┃┏Current depth: 6        27.36%
# ┃┃┃┃┃┃┏Current depth: 7        27.45%
# ┃┃┃┃┃┃┏Current depth: 7        27.54%
# ┃┃┃┃┃┃┏Current depth: 7        27.63%
# ┃┃┃┃┃┏Current depth: 6        27.72%
# ┃┃┃┃┃┃┏Current depth: 7        27.81%
# ┃┃┃┃┃┃┏Current depth: 7        27.90%
# ┃┃┃┃┃┃┏Current depth: 7        28.00%
# ┃┃┃┃┃┏Current depth: 6        28.09%
# ┃┃┃┃┏Current depth: 5        28.18%
# ┃┃┃┃┃┃┏Current depth: 7        28.27%
# ┃┃┃┃┃┃┏Current depth: 7        28.36%
# ┃┃┃┃┃┃┏Current depth: 7        28.45%
# ┃┃┃┃┃┏Current depth: 6        28.55%
# ┃┃┃┃┃┃┏Current depth: 7        28.64%
# ┃┃┃┃┃┃┏Current depth: 7        28.73%
# ┃┃┃┃┃┃┏Current depth: 7        28.82%
# ┃┃┃┃┃┏Current depth: 6        28.91%
# ┃┃┃┃┃┃┏Current depth: 7        29.00%
# ┃┃┃┃┃┃┏Current depth: 7        29.09%
# ┃┃┃┃┃┃┏Current depth: 7        29.19%
# ┃┃┃┃┃┏Current depth: 6        29.28%
# ┃┃┃┃┏Current depth: 5        29.37%
# ┃┃┃┏Current depth: 4        29.46%
# ┃┃┃┃┃┃┏Current depth: 7        29.55%
# ┃┃┃┃┃┃┏Current depth: 7        29.64%
# ┃┃┃┃┃┃┏Current depth: 7        29.73%
# ┃┃┃┃┃┏Current depth: 6        29.83%
# ┃┃┃┃┃┃┏Current depth: 7        29.92%
# ┃┃┃┃┃┃┏Current depth: 7        30.01%
# ┃┃┃┃┃┃┏Current depth: 7        30.10%
# ┃┃┃┃┃┏Current depth: 6        30.19%
# ┃┃┃┃┃┃┏Current depth: 7        30.28%
# ┃┃┃┃┃┃┏Current depth: 7        30.38%
# ┃┃┃┃┃┃┏Current depth: 7        30.47%
# ┃┃┃┃┃┏Current depth: 6        30.56%
# ┃┃┃┃┏Current depth: 5        30.65%
# ┃┃┃┃┃┃┏Current depth: 7        30.74%
# ┃┃┃┃┃┃┏Current depth: 7        30.83%
# ┃┃┃┃┃┃┏Current depth: 7        30.92%
# ┃┃┃┃┃┏Current depth: 6        31.02%
# ┃┃┃┃┃┃┏Current depth: 7        31.11%
# ┃┃┃┃┃┃┏Current depth: 7        31.20%
# ┃┃┃┃┃┃┏Current depth: 7        31.29%
# ┃┃┃┃┃┏Current depth: 6        31.38%
# ┃┃┃┃┃┃┏Current depth: 7        31.47%
# ┃┃┃┃┃┃┏Current depth: 7        31.56%
# ┃┃┃┃┃┃┏Current depth: 7        31.66%
# ┃┃┃┃┃┏Current depth: 6        31.75%
# ┃┃┃┃┏Current depth: 5        31.84%
# ┃┃┃┃┃┃┏Current depth: 7        31.93%
# ┃┃┃┃┃┃┏Current depth: 7        32.02%
# ┃┃┃┃┃┃┏Current depth: 7        32.11%
# ┃┃┃┃┃┏Current depth: 6        32.20%
# ┃┃┃┃┃┃┏Current depth: 7        32.30%
# ┃┃┃┃┃┃┏Current depth: 7        32.39%
# ┃┃┃┃┃┃┏Current depth: 7        32.48%
# ┃┃┃┃┃┏Current depth: 6        32.57%
# ┃┃┃┃┃┃┏Current depth: 7        32.66%
# ┃┃┃┃┃┃┏Current depth: 7        32.75%
# ┃┃┃┃┃┃┏Current depth: 7        32.85%
# ┃┃┃┃┃┏Current depth: 6        32.94%
# ┃┃┃┃┏Current depth: 5        33.03%
# ┃┃┃┏Current depth: 4        33.12%
# ┃┃┏Current depth: 3        33.21%
# ┃┏Current depth: 2        33.30%
# ┃┃┃┃┃┃┏Current depth: 7        33.39%
# ┃┃┃┃┃┃┏Current depth: 7        33.49%
# ┃┃┃┃┃┃┏Current depth: 7        33.58%
# ┃┃┃┃┃┏Current depth: 6        33.67%
# ┃┃┃┃┃┃┏Current depth: 7        33.76%
# ┃┃┃┃┃┃┏Current depth: 7        33.85%
# ┃┃┃┃┃┃┏Current depth: 7        33.94%
# ┃┃┃┃┃┏Current depth: 6        34.03%
# ┃┃┃┃┃┃┏Current depth: 7        34.13%
# ┃┃┃┃┃┃┏Current depth: 7        34.22%
# ┃┃┃┃┃┃┏Current depth: 7        34.31%
# ┃┃┃┃┃┏Current depth: 6        34.40%
# ┃┃┃┃┏Current depth: 5        34.49%
# ┃┃┃┃┃┃┏Current depth: 7        34.58%
# ┃┃┃┃┃┃┏Current depth: 7        34.68%
# ┃┃┃┃┃┃┏Current depth: 7        34.77%
# ┃┃┃┃┃┏Current depth: 6        34.86%
# ┃┃┃┃┃┃┏Current depth: 7        34.95%
# ┃┃┃┃┃┃┏Current depth: 7        35.04%
# ┃┃┃┃┃┃┏Current depth: 7        35.13%
# ┃┃┃┃┃┏Current depth: 6        35.22%
# ┃┃┃┃┃┃┏Current depth: 7        35.32%
# ┃┃┃┃┃┃┏Current depth: 7        35.41%
# ┃┃┃┃┃┃┏Current depth: 7        35.50%
# ┃┃┃┃┃┏Current depth: 6        35.59%
# ┃┃┃┃┏Current depth: 5        35.68%
# ┃┃┃┃┃┃┏Current depth: 7        35.77%
# ┃┃┃┃┃┃┏Current depth: 7        35.86%
# ┃┃┃┃┃┃┏Current depth: 7        35.96%
# ┃┃┃┃┃┏Current depth: 6        36.05%
# ┃┃┃┃┃┃┏Current depth: 7        36.14%
# ┃┃┃┃┃┃┏Current depth: 7        36.23%
# ┃┃┃┃┃┃┏Current depth: 7        36.32%
# ┃┃┃┃┃┏Current depth: 6        36.41%
# ┃┃┃┃┃┃┏Current depth: 7        36.51%
# ┃┃┃┃┃┃┏Current depth: 7        36.60%
# ┃┃┃┃┃┃┏Current depth: 7        36.69%
# ┃┃┃┃┃┏Current depth: 6        36.78%
# ┃┃┃┃┏Current depth: 5        36.87%
# ┃┃┃┏Current depth: 4        36.96%
# ┃┃┃┃┃┃┏Current depth: 7        37.05%
# ┃┃┃┃┃┃┏Current depth: 7        37.15%
# ┃┃┃┃┃┃┏Current depth: 7        37.24%
# ┃┃┃┃┃┏Current depth: 6        37.33%
# ┃┃┃┃┃┃┏Current depth: 7        37.42%
# ┃┃┃┃┃┃┏Current depth: 7        37.51%
# ┃┃┃┃┃┃┏Current depth: 7        37.60%
# ┃┃┃┃┃┏Current depth: 6        37.69%
# ┃┃┃┃┃┃┏Current depth: 7        37.79%
# ┃┃┃┃┃┃┏Current depth: 7        37.88%
# ┃┃┃┃┃┃┏Current depth: 7        37.97%
# ┃┃┃┃┃┏Current depth: 6        38.06%
# ┃┃┃┃┏Current depth: 5        38.15%
# ┃┃┃┃┃┃┏Current depth: 7        38.24%
# ┃┃┃┃┃┃┏Current depth: 7        38.33%
# ┃┃┃┃┃┃┏Current depth: 7        38.43%
# ┃┃┃┃┃┏Current depth: 6        38.52%
# ┃┃┃┃┃┃┏Current depth: 7        38.61%
# ┃┃┃┃┃┃┏Current depth: 7        38.70%
# ┃┃┃┃┃┃┏Current depth: 7        38.79%
# ┃┃┃┃┃┏Current depth: 6        38.88%
# ┃┃┃┃┃┃┏Current depth: 7        38.98%
# ┃┃┃┃┃┃┏Current depth: 7        39.07%
# ┃┃┃┃┃┃┏Current depth: 7        39.16%
# ┃┃┃┃┃┏Current depth: 6        39.25%
# ┃┃┃┃┏Current depth: 5        39.34%
# ┃┃┃┃┃┃┏Current depth: 7        39.43%
# ┃┃┃┃┃┃┏Current depth: 7        39.52%
# ┃┃┃┃┃┃┏Current depth: 7        39.62%
# ┃┃┃┃┃┏Current depth: 6        39.71%
# ┃┃┃┃┃┃┏Current depth: 7        39.80%
# ┃┃┃┃┃┃┏Current depth: 7        39.89%
# ┃┃┃┃┃┃┏Current depth: 7        39.98%
# ┃┃┃┃┃┏Current depth: 6        40.07%
# ┃┃┃┃┃┃┏Current depth: 7        40.16%
# ┃┃┃┃┃┃┏Current depth: 7        40.26%
# ┃┃┃┃┃┃┏Current depth: 7        40.35%
# ┃┃┃┃┃┏Current depth: 6        40.44%
# ┃┃┃┃┏Current depth: 5        40.53%
# ┃┃┃┏Current depth: 4        40.62%
# ┃┃┃┃┃┃┏Current depth: 7        40.71%
# ┃┃┃┃┃┃┏Current depth: 7        40.81%
# ┃┃┃┃┃┃┏Current depth: 7        40.90%
# ┃┃┃┃┃┏Current depth: 6        40.99%
# ┃┃┃┃┃┃┏Current depth: 7        41.08%
# ┃┃┃┃┃┃┏Current depth: 7        41.17%
# ┃┃┃┃┃┃┏Current depth: 7        41.26%
# ┃┃┃┃┃┏Current depth: 6        41.35%
# ┃┃┃┃┃┃┏Current depth: 7        41.45%
# ┃┃┃┃┃┃┏Current depth: 7        41.54%
# ┃┃┃┃┃┃┏Current depth: 7        41.63%
# ┃┃┃┃┃┏Current depth: 6        41.72%
# ┃┃┃┃┏Current depth: 5        41.81%
# ┃┃┃┃┃┃┏Current depth: 7        41.90%
# ┃┃┃┃┃┃┏Current depth: 7        41.99%
# ┃┃┃┃┃┃┏Current depth: 7        42.09%
# ┃┃┃┃┃┏Current depth: 6        42.18%
# ┃┃┃┃┃┃┏Current depth: 7        42.27%
# ┃┃┃┃┃┃┏Current depth: 7        42.36%
# ┃┃┃┃┃┃┏Current depth: 7        42.45%
# ┃┃┃┃┃┏Current depth: 6        42.54%
# ┃┃┃┃┃┃┏Current depth: 7        42.63%
# ┃┃┃┃┃┃┏Current depth: 7        42.73%
# ┃┃┃┃┃┃┏Current depth: 7        42.82%
# ┃┃┃┃┃┏Current depth: 6        42.91%
# ┃┃┃┃┏Current depth: 5        43.00%
# ┃┃┃┃┃┃┏Current depth: 7        43.09%
# ┃┃┃┃┃┃┏Current depth: 7        43.18%
# ┃┃┃┃┃┃┏Current depth: 7        43.28%
# ┃┃┃┃┃┏Current depth: 6        43.37%
# ┃┃┃┃┃┃┏Current depth: 7        43.46%
# ┃┃┃┃┃┃┏Current depth: 7        43.55%
# ┃┃┃┃┃┃┏Current depth: 7        43.64%
# ┃┃┃┃┃┏Current depth: 6        43.73%
# ┃┃┃┃┃┃┏Current depth: 7        43.82%
# ┃┃┃┃┃┃┏Current depth: 7        43.92%
# ┃┃┃┃┃┃┏Current depth: 7        44.01%
# ┃┃┃┃┃┏Current depth: 6        44.10%
# ┃┃┃┃┏Current depth: 5        44.19%
# ┃┃┃┏Current depth: 4        44.28%
# ┃┃┏Current depth: 3        44.37%
# ┃┃┃┃┃┃┏Current depth: 7        44.46%
# ┃┃┃┃┃┃┏Current depth: 7        44.56%
# ┃┃┃┃┃┃┏Current depth: 7        44.65%
# ┃┃┃┃┃┏Current depth: 6        44.74%
# ┃┃┃┃┃┃┏Current depth: 7        44.83%
# ┃┃┃┃┃┃┏Current depth: 7        44.92%
# ┃┃┃┃┃┃┏Current depth: 7        45.01%
# ┃┃┃┃┃┏Current depth: 6        45.11%
# ┃┃┃┃┃┃┏Current depth: 7        45.20%
# ┃┃┃┃┃┃┏Current depth: 7        45.29%
# ┃┃┃┃┃┃┏Current depth: 7        45.38%
# ┃┃┃┃┃┏Current depth: 6        45.47%
# ┃┃┃┃┏Current depth: 5        45.56%
# ┃┃┃┃┃┃┏Current depth: 7        45.65%
# ┃┃┃┃┃┃┏Current depth: 7        45.75%
# ┃┃┃┃┃┃┏Current depth: 7        45.84%
# ┃┃┃┃┃┏Current depth: 6        45.93%
# ┃┃┃┃┃┃┏Current depth: 7        46.02%
# ┃┃┃┃┃┃┏Current depth: 7        46.11%
# ┃┃┃┃┃┃┏Current depth: 7        46.20%
# ┃┃┃┃┃┏Current depth: 6        46.29%
# ┃┃┃┃┃┃┏Current depth: 7        46.39%
# ┃┃┃┃┃┃┏Current depth: 7        46.48%
# ┃┃┃┃┃┃┏Current depth: 7        46.57%
# ┃┃┃┃┃┏Current depth: 6        46.66%
# ┃┃┃┃┏Current depth: 5        46.75%
# ┃┃┃┃┃┃┏Current depth: 7        46.84%
# ┃┃┃┃┃┃┏Current depth: 7        46.94%
# ┃┃┃┃┃┃┏Current depth: 7        47.03%
# ┃┃┃┃┃┏Current depth: 6        47.12%
# ┃┃┃┃┃┃┏Current depth: 7        47.21%
# ┃┃┃┃┃┃┏Current depth: 7        47.30%
# ┃┃┃┃┃┃┏Current depth: 7        47.39%
# ┃┃┃┃┃┏Current depth: 6        47.48%
# ┃┃┃┃┃┃┏Current depth: 7        47.58%
# ┃┃┃┃┃┃┏Current depth: 7        47.67%
# ┃┃┃┃┃┃┏Current depth: 7        47.76%
# ┃┃┃┃┃┏Current depth: 6        47.85%
# ┃┃┃┃┏Current depth: 5        47.94%
# ┃┃┃┏Current depth: 4        48.03%
# ┃┃┃┃┃┃┏Current depth: 7        48.12%
# ┃┃┃┃┃┃┏Current depth: 7        48.22%
# ┃┃┃┃┃┃┏Current depth: 7        48.31%
# ┃┃┃┃┃┏Current depth: 6        48.40%
# ┃┃┃┃┃┃┏Current depth: 7        48.49%
# ┃┃┃┃┃┃┏Current depth: 7        48.58%
# ┃┃┃┃┃┃┏Current depth: 7        48.67%
# ┃┃┃┃┃┏Current depth: 6        48.76%
# ┃┃┃┃┃┃┏Current depth: 7        48.86%
# ┃┃┃┃┃┃┏Current depth: 7        48.95%
# ┃┃┃┃┃┃┏Current depth: 7        49.04%
# ┃┃┃┃┃┏Current depth: 6        49.13%
# ┃┃┃┃┏Current depth: 5        49.22%
# ┃┃┃┃┃┃┏Current depth: 7        49.31%
# ┃┃┃┃┃┃┏Current depth: 7        49.41%
# ┃┃┃┃┃┃┏Current depth: 7        49.50%
# ┃┃┃┃┃┏Current depth: 6        49.59%
# ┃┃┃┃┃┃┏Current depth: 7        49.68%
# ┃┃┃┃┃┃┏Current depth: 7        49.77%
# ┃┃┃┃┃┃┏Current depth: 7        49.86%
# ┃┃┃┃┃┏Current depth: 6        49.95%
# ┃┃┃┃┃┃┏Current depth: 7        50.05%
# ┃┃┃┃┃┃┏Current depth: 7        50.14%
# ┃┃┃┃┃┃┏Current depth: 7        50.23%
# ┃┃┃┃┃┏Current depth: 6        50.32%
# ┃┃┃┃┏Current depth: 5        50.41%
# ┃┃┃┃┃┃┏Current depth: 7        50.50%
# ┃┃┃┃┃┃┏Current depth: 7        50.59%
# ┃┃┃┃┃┃┏Current depth: 7        50.69%
# ┃┃┃┃┃┏Current depth: 6        50.78%
# ┃┃┃┃┃┃┏Current depth: 7        50.87%
# ┃┃┃┃┃┃┏Current depth: 7        50.96%
# ┃┃┃┃┃┃┏Current depth: 7        51.05%
# ┃┃┃┃┃┏Current depth: 6        51.14%
# ┃┃┃┃┃┃┏Current depth: 7        51.24%
# ┃┃┃┃┃┃┏Current depth: 7        51.33%
# ┃┃┃┃┃┃┏Current depth: 7        51.42%
# ┃┃┃┃┃┏Current depth: 6        51.51%
# ┃┃┃┃┏Current depth: 5        51.60%
# ┃┃┃┏Current depth: 4        51.69%
# ┃┃┃┃┃┃┏Current depth: 7        51.78%
# ┃┃┃┃┃┃┏Current depth: 7        51.88%
# ┃┃┃┃┃┃┏Current depth: 7        51.97%
# ┃┃┃┃┃┏Current depth: 6        52.06%
# ┃┃┃┃┃┃┏Current depth: 7        52.15%
# ┃┃┃┃┃┃┏Current depth: 7        52.24%
# ┃┃┃┃┃┃┏Current depth: 7        52.33%
# ┃┃┃┃┃┏Current depth: 6        52.42%
# ┃┃┃┃┃┃┏Current depth: 7        52.52%
# ┃┃┃┃┃┃┏Current depth: 7        52.61%
# ┃┃┃┃┃┃┏Current depth: 7        52.70%
# ┃┃┃┃┃┏Current depth: 6        52.79%
# ┃┃┃┃┏Current depth: 5        52.88%
# ┃┃┃┃┃┃┏Current depth: 7        52.97%
# ┃┃┃┃┃┃┏Current depth: 7        53.06%
# ┃┃┃┃┃┃┏Current depth: 7        53.16%
# ┃┃┃┃┃┏Current depth: 6        53.25%
# ┃┃┃┃┃┃┏Current depth: 7        53.34%
# ┃┃┃┃┃┃┏Current depth: 7        53.43%
# ┃┃┃┃┃┃┏Current depth: 7        53.52%
# ┃┃┃┃┃┏Current depth: 6        53.61%
# ┃┃┃┃┃┃┏Current depth: 7        53.71%
# ┃┃┃┃┃┃┏Current depth: 7        53.80%
# ┃┃┃┃┃┃┏Current depth: 7        53.89%
# ┃┃┃┃┃┏Current depth: 6        53.98%
# ┃┃┃┃┏Current depth: 5        54.07%
# ┃┃┃┃┃┃┏Current depth: 7        54.16%
# ┃┃┃┃┃┃┏Current depth: 7        54.25%
# ┃┃┃┃┃┃┏Current depth: 7        54.35%
# ┃┃┃┃┃┏Current depth: 6        54.44%
# ┃┃┃┃┃┃┏Current depth: 7        54.53%
# ┃┃┃┃┃┃┏Current depth: 7        54.62%
# ┃┃┃┃┃┃┏Current depth: 7        54.71%
# ┃┃┃┃┃┏Current depth: 6        54.80%
# ┃┃┃┃┃┃┏Current depth: 7        54.89%
# ┃┃┃┃┃┃┏Current depth: 7        54.99%
# ┃┃┃┃┃┃┏Current depth: 7        55.08%
# ┃┃┃┃┃┏Current depth: 6        55.17%
# ┃┃┃┃┏Current depth: 5        55.26%
# ┃┃┃┏Current depth: 4        55.35%
# ┃┃┏Current depth: 3        55.44%
# ┃┃┃┃┃┃┏Current depth: 7        55.54%
# ┃┃┃┃┃┃┏Current depth: 7        55.63%
# ┃┃┃┃┃┃┏Current depth: 7        55.72%
# ┃┃┃┃┃┏Current depth: 6        55.81%
# ┃┃┃┃┃┃┏Current depth: 7        55.90%
# ┃┃┃┃┃┃┏Current depth: 7        55.99%
# ┃┃┃┃┃┃┏Current depth: 7        56.08%
# ┃┃┃┃┃┏Current depth: 6        56.18%
# ┃┃┃┃┃┃┏Current depth: 7        56.27%
# ┃┃┃┃┃┃┏Current depth: 7        56.36%
# ┃┃┃┃┃┃┏Current depth: 7        56.45%
# ┃┃┃┃┃┏Current depth: 6        56.54%
# ┃┃┃┃┏Current depth: 5        56.63%
# ┃┃┃┃┃┃┏Current depth: 7        56.72%
# ┃┃┃┃┃┃┏Current depth: 7        56.82%
# ┃┃┃┃┃┃┏Current depth: 7        56.91%
# ┃┃┃┃┃┏Current depth: 6        57.00%
# ┃┃┃┃┃┃┏Current depth: 7        57.09%
# ┃┃┃┃┃┃┏Current depth: 7        57.18%
# ┃┃┃┃┃┃┏Current depth: 7        57.27%
# ┃┃┃┃┃┏Current depth: 6        57.37%
# ┃┃┃┃┃┃┏Current depth: 7        57.46%
# ┃┃┃┃┃┃┏Current depth: 7        57.55%
# ┃┃┃┃┃┃┏Current depth: 7        57.64%
# ┃┃┃┃┃┏Current depth: 6        57.73%
# ┃┃┃┃┏Current depth: 5        57.82%
# ┃┃┃┃┃┃┏Current depth: 7        57.91%
# ┃┃┃┃┃┃┏Current depth: 7        58.01%
# ┃┃┃┃┃┃┏Current depth: 7        58.10%
# ┃┃┃┃┃┏Current depth: 6        58.19%
# ┃┃┃┃┃┃┏Current depth: 7        58.28%
# ┃┃┃┃┃┃┏Current depth: 7        58.37%
# ┃┃┃┃┃┃┏Current depth: 7        58.46%
# ┃┃┃┃┃┏Current depth: 6        58.55%
# ┃┃┃┃┃┃┏Current depth: 7        58.65%
# ┃┃┃┃┃┃┏Current depth: 7        58.74%
# ┃┃┃┃┃┃┏Current depth: 7        58.83%
# ┃┃┃┃┃┏Current depth: 6        58.92%
# ┃┃┃┃┏Current depth: 5        59.01%
# ┃┃┃┏Current depth: 4        59.10%
# ┃┃┃┃┃┃┏Current depth: 7        59.19%
# ┃┃┃┃┃┃┏Current depth: 7        59.29%
# ┃┃┃┃┃┃┏Current depth: 7        59.38%
# ┃┃┃┃┃┏Current depth: 6        59.47%
# ┃┃┃┃┃┃┏Current depth: 7        59.56%
# ┃┃┃┃┃┃┏Current depth: 7        59.65%
# ┃┃┃┃┃┃┏Current depth: 7        59.74%
# ┃┃┃┃┃┏Current depth: 6        59.84%
# ┃┃┃┃┃┃┏Current depth: 7        59.93%
# ┃┃┃┃┃┃┏Current depth: 7        60.02%
# ┃┃┃┃┃┃┏Current depth: 7        60.11%
# ┃┃┃┃┃┏Current depth: 6        60.20%
# ┃┃┃┃┏Current depth: 5        60.29%
# ┃┃┃┃┃┃┏Current depth: 7        60.38%
# ┃┃┃┃┃┃┏Current depth: 7        60.48%
# ┃┃┃┃┃┃┏Current depth: 7        60.57%
# ┃┃┃┃┃┏Current depth: 6        60.66%
# ┃┃┃┃┃┃┏Current depth: 7        60.75%
# ┃┃┃┃┃┃┏Current depth: 7        60.84%
# ┃┃┃┃┃┃┏Current depth: 7        60.93%
# ┃┃┃┃┃┏Current depth: 6        61.02%
# ┃┃┃┃┃┃┏Current depth: 7        61.12%
# ┃┃┃┃┃┃┏Current depth: 7        61.21%
# ┃┃┃┃┃┃┏Current depth: 7        61.30%
# ┃┃┃┃┃┏Current depth: 6        61.39%
# ┃┃┃┃┏Current depth: 5        61.48%
# ┃┃┃┃┃┃┏Current depth: 7        61.57%
# ┃┃┃┃┃┃┏Current depth: 7        61.67%
# ┃┃┃┃┃┃┏Current depth: 7        61.76%
# ┃┃┃┃┃┏Current depth: 6        61.85%
# ┃┃┃┃┃┃┏Current depth: 7        61.94%
# ┃┃┃┃┃┃┏Current depth: 7        62.03%
# ┃┃┃┃┃┃┏Current depth: 7        62.12%
# ┃┃┃┃┃┏Current depth: 6        62.21%
# ┃┃┃┃┃┃┏Current depth: 7        62.31%
# ┃┃┃┃┃┃┏Current depth: 7        62.40%
# ┃┃┃┃┃┃┏Current depth: 7        62.49%
# ┃┃┃┃┃┏Current depth: 6        62.58%
# ┃┃┃┃┏Current depth: 5        62.67%
# ┃┃┃┏Current depth: 4        62.76%
# ┃┃┃┃┃┃┏Current depth: 7        62.85%
# ┃┃┃┃┃┃┏Current depth: 7        62.95%
# ┃┃┃┃┃┃┏Current depth: 7        63.04%
# ┃┃┃┃┃┏Current depth: 6        63.13%
# ┃┃┃┃┃┃┏Current depth: 7        63.22%
# ┃┃┃┃┃┃┏Current depth: 7        63.31%
# ┃┃┃┃┃┃┏Current depth: 7        63.40%
# ┃┃┃┃┃┏Current depth: 6        63.49%
# ┃┃┃┃┃┃┏Current depth: 7        63.59%
# ┃┃┃┃┃┃┏Current depth: 7        63.68%
# ┃┃┃┃┃┃┏Current depth: 7        63.77%
# ┃┃┃┃┃┏Current depth: 6        63.86%
# ┃┃┃┃┏Current depth: 5        63.95%
# ┃┃┃┃┃┃┏Current depth: 7        64.04%
# ┃┃┃┃┃┃┏Current depth: 7        64.14%
# ┃┃┃┃┃┃┏Current depth: 7        64.23%
# ┃┃┃┃┃┏Current depth: 6        64.32%
# ┃┃┃┃┃┃┏Current depth: 7        64.41%
# ┃┃┃┃┃┃┏Current depth: 7        64.50%
# ┃┃┃┃┃┃┏Current depth: 7        64.59%
# ┃┃┃┃┃┏Current depth: 6        64.68%
# ┃┃┃┃┃┃┏Current depth: 7        64.78%
# ┃┃┃┃┃┃┏Current depth: 7        64.87%
# ┃┃┃┃┃┃┏Current depth: 7        64.96%
# ┃┃┃┃┃┏Current depth: 6        65.05%
# ┃┃┃┃┏Current depth: 5        65.14%
# ┃┃┃┃┃┃┏Current depth: 7        65.23%
# ┃┃┃┃┃┃┏Current depth: 7        65.32%
# ┃┃┃┃┃┃┏Current depth: 7        65.42%
# ┃┃┃┃┃┏Current depth: 6        65.51%
# ┃┃┃┃┃┃┏Current depth: 7        65.60%
# ┃┃┃┃┃┃┏Current depth: 7        65.69%
# ┃┃┃┃┃┃┏Current depth: 7        65.78%
# ┃┃┃┃┃┏Current depth: 6        65.87%
# ┃┃┃┃┃┃┏Current depth: 7        65.97%
# ┃┃┃┃┃┃┏Current depth: 7        66.06%
# ┃┃┃┃┃┃┏Current depth: 7        66.15%
# ┃┃┃┃┃┏Current depth: 6        66.24%
# ┃┃┃┃┏Current depth: 5        66.33%
# ┃┃┃┏Current depth: 4        66.42%
# ┃┃┏Current depth: 3        66.51%
# ┃┏Current depth: 2        66.61%
# ┃┃┃┃┃┃┏Current depth: 7        66.70%
# ┃┃┃┃┃┃┏Current depth: 7        66.79%
# ┃┃┃┃┃┃┏Current depth: 7        66.88%
# ┃┃┃┃┃┏Current depth: 6        66.97%
# ┃┃┃┃┃┃┏Current depth: 7        67.06%
# ┃┃┃┃┃┃┏Current depth: 7        67.15%
# ┃┃┃┃┃┃┏Current depth: 7        67.25%
# ┃┃┃┃┃┏Current depth: 6        67.34%
# ┃┃┃┃┃┃┏Current depth: 7        67.43%
# ┃┃┃┃┃┃┏Current depth: 7        67.52%
# ┃┃┃┃┃┃┏Current depth: 7        67.61%
# ┃┃┃┃┃┏Current depth: 6        67.70%
# ┃┃┃┃┏Current depth: 5        67.80%
# ┃┃┃┃┃┃┏Current depth: 7        67.89%
# ┃┃┃┃┃┃┏Current depth: 7        67.98%
# ┃┃┃┃┃┃┏Current depth: 7        68.07%
# ┃┃┃┃┃┏Current depth: 6        68.16%
# ┃┃┃┃┃┃┏Current depth: 7        68.25%
# ┃┃┃┃┃┃┏Current depth: 7        68.34%
# ┃┃┃┃┃┃┏Current depth: 7        68.44%
# ┃┃┃┃┃┏Current depth: 6        68.53%
# ┃┃┃┃┃┃┏Current depth: 7        68.62%
# ┃┃┃┃┃┃┏Current depth: 7        68.71%
# ┃┃┃┃┃┃┏Current depth: 7        68.80%
# ┃┃┃┃┃┏Current depth: 6        68.89%
# ┃┃┃┃┏Current depth: 5        68.98%
# ┃┃┃┃┃┃┏Current depth: 7        69.08%
# ┃┃┃┃┃┃┏Current depth: 7        69.17%
# ┃┃┃┃┃┃┏Current depth: 7        69.26%
# ┃┃┃┃┃┏Current depth: 6        69.35%
# ┃┃┃┃┃┃┏Current depth: 7        69.44%
# ┃┃┃┃┃┃┏Current depth: 7        69.53%
# ┃┃┃┃┃┃┏Current depth: 7        69.62%
# ┃┃┃┃┃┏Current depth: 6        69.72%
# ┃┃┃┃┃┃┏Current depth: 7        69.81%
# ┃┃┃┃┃┃┏Current depth: 7        69.90%
# ┃┃┃┃┃┃┏Current depth: 7        69.99%
# ┃┃┃┃┃┏Current depth: 6        70.08%
# ┃┃┃┃┏Current depth: 5        70.17%
# ┃┃┃┏Current depth: 4        70.27%
# ┃┃┃┃┃┃┏Current depth: 7        70.36%
# ┃┃┃┃┃┃┏Current depth: 7        70.45%
# ┃┃┃┃┃┃┏Current depth: 7        70.54%
# ┃┃┃┃┃┏Current depth: 6        70.63%
# ┃┃┃┃┃┃┏Current depth: 7        70.72%
# ┃┃┃┃┃┃┏Current depth: 7        70.81%
# ┃┃┃┃┃┃┏Current depth: 7        70.91%
# ┃┃┃┃┃┏Current depth: 6        71.00%
# ┃┃┃┃┃┃┏Current depth: 7        71.09%
# ┃┃┃┃┃┃┏Current depth: 7        71.18%
# ┃┃┃┃┃┃┏Current depth: 7        71.27%
# ┃┃┃┃┃┏Current depth: 6        71.36%
# ┃┃┃┃┏Current depth: 5        71.45%
# ┃┃┃┃┃┃┏Current depth: 7        71.55%
# ┃┃┃┃┃┃┏Current depth: 7        71.64%
# ┃┃┃┃┃┃┏Current depth: 7        71.73%
# ┃┃┃┃┃┏Current depth: 6        71.82%
# ┃┃┃┃┃┃┏Current depth: 7        71.91%
# ┃┃┃┃┃┃┏Current depth: 7        72.00%
# ┃┃┃┃┃┃┏Current depth: 7        72.10%
# ┃┃┃┃┃┏Current depth: 6        72.19%
# ┃┃┃┃┃┃┏Current depth: 7        72.28%
# ┃┃┃┃┃┃┏Current depth: 7        72.37%
# ┃┃┃┃┃┃┏Current depth: 7        72.46%
# ┃┃┃┃┃┏Current depth: 6        72.55%
# ┃┃┃┃┏Current depth: 5        72.64%
# ┃┃┃┃┃┃┏Current depth: 7        72.74%
# ┃┃┃┃┃┃┏Current depth: 7        72.83%
# ┃┃┃┃┃┃┏Current depth: 7        72.92%
# ┃┃┃┃┃┏Current depth: 6        73.01%
# ┃┃┃┃┃┃┏Current depth: 7        73.10%
# ┃┃┃┃┃┃┏Current depth: 7        73.19%
# ┃┃┃┃┃┃┏Current depth: 7        73.28%
# ┃┃┃┃┃┏Current depth: 6        73.38%
# ┃┃┃┃┃┃┏Current depth: 7        73.47%
# ┃┃┃┃┃┃┏Current depth: 7        73.56%
# ┃┃┃┃┃┃┏Current depth: 7        73.65%
# ┃┃┃┃┃┏Current depth: 6        73.74%
# ┃┃┃┃┏Current depth: 5        73.83%
# ┃┃┃┏Current depth: 4        73.92%
# ┃┃┃┃┃┃┏Current depth: 7        74.02%
# ┃┃┃┃┃┃┏Current depth: 7        74.11%
# ┃┃┃┃┃┃┏Current depth: 7        74.20%
# ┃┃┃┃┃┏Current depth: 6        74.29%
# ┃┃┃┃┃┃┏Current depth: 7        74.38%
# ┃┃┃┃┃┃┏Current depth: 7        74.47%
# ┃┃┃┃┃┃┏Current depth: 7        74.57%
# ┃┃┃┃┃┏Current depth: 6        74.66%
# ┃┃┃┃┃┃┏Current depth: 7        74.75%
# ┃┃┃┃┃┃┏Current depth: 7        74.84%
# ┃┃┃┃┃┃┏Current depth: 7        74.93%
# ┃┃┃┃┃┏Current depth: 6        75.02%
# ┃┃┃┃┏Current depth: 5        75.11%
# ┃┃┃┃┃┃┏Current depth: 7        75.21%
# ┃┃┃┃┃┃┏Current depth: 7        75.30%
# ┃┃┃┃┃┃┏Current depth: 7        75.39%
# ┃┃┃┃┃┏Current depth: 6        75.48%
# ┃┃┃┃┃┃┏Current depth: 7        75.57%
# ┃┃┃┃┃┃┏Current depth: 7        75.66%
# ┃┃┃┃┃┃┏Current depth: 7        75.75%
# ┃┃┃┃┃┏Current depth: 6        75.85%
# ┃┃┃┃┃┃┏Current depth: 7        75.94%
# ┃┃┃┃┃┃┏Current depth: 7        76.03%
# ┃┃┃┃┃┃┏Current depth: 7        76.12%
# ┃┃┃┃┃┏Current depth: 6        76.21%
# ┃┃┃┃┏Current depth: 5        76.30%
# ┃┃┃┃┃┃┏Current depth: 7        76.40%
# ┃┃┃┃┃┃┏Current depth: 7        76.49%
# ┃┃┃┃┃┃┏Current depth: 7        76.58%
# ┃┃┃┃┃┏Current depth: 6        76.67%
# ┃┃┃┃┃┃┏Current depth: 7        76.76%
# ┃┃┃┃┃┃┏Current depth: 7        76.85%
# ┃┃┃┃┃┃┏Current depth: 7        76.94%
# ┃┃┃┃┃┏Current depth: 6        77.04%
# ┃┃┃┃┃┃┏Current depth: 7        77.13%
# ┃┃┃┃┃┃┏Current depth: 7        77.22%
# ┃┃┃┃┃┃┏Current depth: 7        77.31%
# ┃┃┃┃┃┏Current depth: 6        77.40%
# ┃┃┃┃┏Current depth: 5        77.49%
# ┃┃┃┏Current depth: 4        77.58%
# ┃┃┏Current depth: 3        77.68%
# ┃┃┃┃┃┃┏Current depth: 7        77.77%
# ┃┃┃┃┃┃┏Current depth: 7        77.86%
# ┃┃┃┃┃┃┏Current depth: 7        77.95%
# ┃┃┃┃┃┏Current depth: 6        78.04%
# ┃┃┃┃┃┃┏Current depth: 7        78.13%
# ┃┃┃┃┃┃┏Current depth: 7        78.23%
# ┃┃┃┃┃┃┏Current depth: 7        78.32%
# ┃┃┃┃┃┏Current depth: 6        78.41%
# ┃┃┃┃┃┃┏Current depth: 7        78.50%
# ┃┃┃┃┃┃┏Current depth: 7        78.59%
# ┃┃┃┃┃┃┏Current depth: 7        78.68%
# ┃┃┃┃┃┏Current depth: 6        78.77%
# ┃┃┃┃┏Current depth: 5        78.87%
# ┃┃┃┃┃┃┏Current depth: 7        78.96%
# ┃┃┃┃┃┃┏Current depth: 7        79.05%
# ┃┃┃┃┃┃┏Current depth: 7        79.14%
# ┃┃┃┃┃┏Current depth: 6        79.23%
# ┃┃┃┃┃┃┏Current depth: 7        79.32%
# ┃┃┃┃┃┃┏Current depth: 7        79.41%
# ┃┃┃┃┃┃┏Current depth: 7        79.51%
# ┃┃┃┃┃┏Current depth: 6        79.60%
# ┃┃┃┃┃┃┏Current depth: 7        79.69%
# ┃┃┃┃┃┃┏Current depth: 7        79.78%
# ┃┃┃┃┃┃┏Current depth: 7        79.87%
# ┃┃┃┃┃┏Current depth: 6        79.96%
# ┃┃┃┃┏Current depth: 5        80.05%
# ┃┃┃┃┃┃┏Current depth: 7        80.15%
# ┃┃┃┃┃┃┏Current depth: 7        80.24%
# ┃┃┃┃┃┃┏Current depth: 7        80.33%
# ┃┃┃┃┃┏Current depth: 6        80.42%
# ┃┃┃┃┃┃┏Current depth: 7        80.51%
# ┃┃┃┃┃┃┏Current depth: 7        80.60%
# ┃┃┃┃┃┃┏Current depth: 7        80.70%
# ┃┃┃┃┃┏Current depth: 6        80.79%
# ┃┃┃┃┃┃┏Current depth: 7        80.88%
# ┃┃┃┃┃┃┏Current depth: 7        80.97%
# ┃┃┃┃┃┃┏Current depth: 7        81.06%
# ┃┃┃┃┃┏Current depth: 6        81.15%
# ┃┃┃┃┏Current depth: 5        81.24%
# ┃┃┃┏Current depth: 4        81.34%
# ┃┃┃┃┃┃┏Current depth: 7        81.43%
# ┃┃┃┃┃┃┏Current depth: 7        81.52%
# ┃┃┃┃┃┃┏Current depth: 7        81.61%
# ┃┃┃┃┃┏Current depth: 6        81.70%
# ┃┃┃┃┃┃┏Current depth: 7        81.79%
# ┃┃┃┃┃┃┏Current depth: 7        81.88%
# ┃┃┃┃┃┃┏Current depth: 7        81.98%
# ┃┃┃┃┃┏Current depth: 6        82.07%
# ┃┃┃┃┃┃┏Current depth: 7        82.16%
# ┃┃┃┃┃┃┏Current depth: 7        82.25%
# ┃┃┃┃┃┃┏Current depth: 7        82.34%
# ┃┃┃┃┃┏Current depth: 6        82.43%
# ┃┃┃┃┏Current depth: 5        82.53%
# ┃┃┃┃┃┃┏Current depth: 7        82.62%
# ┃┃┃┃┃┃┏Current depth: 7        82.71%
# ┃┃┃┃┃┃┏Current depth: 7        82.80%
# ┃┃┃┃┃┏Current depth: 6        82.89%
# ┃┃┃┃┃┃┏Current depth: 7        82.98%
# ┃┃┃┃┃┃┏Current depth: 7        83.07%
# ┃┃┃┃┃┃┏Current depth: 7        83.17%
# ┃┃┃┃┃┏Current depth: 6        83.26%
# ┃┃┃┃┃┃┏Current depth: 7        83.35%
# ┃┃┃┃┃┃┏Current depth: 7        83.44%
# ┃┃┃┃┃┃┏Current depth: 7        83.53%
# ┃┃┃┃┃┏Current depth: 6        83.62%
# ┃┃┃┃┏Current depth: 5        83.71%
# ┃┃┃┃┃┃┏Current depth: 7        83.81%
# ┃┃┃┃┃┃┏Current depth: 7        83.90%
# ┃┃┃┃┃┃┏Current depth: 7        83.99%
# ┃┃┃┃┃┏Current depth: 6        84.08%
# ┃┃┃┃┃┃┏Current depth: 7        84.17%
# ┃┃┃┃┃┃┏Current depth: 7        84.26%
# ┃┃┃┃┃┃┏Current depth: 7        84.35%
# ┃┃┃┃┃┏Current depth: 6        84.45%
# ┃┃┃┃┃┃┏Current depth: 7        84.54%
# ┃┃┃┃┃┃┏Current depth: 7        84.63%
# ┃┃┃┃┃┃┏Current depth: 7        84.72%
# ┃┃┃┃┃┏Current depth: 6        84.81%
# ┃┃┃┃┏Current depth: 5        84.90%
# ┃┃┃┏Current depth: 4        85.00%
# ┃┃┃┃┃┃┏Current depth: 7        85.09%
# ┃┃┃┃┃┃┏Current depth: 7        85.18%
# ┃┃┃┃┃┃┏Current depth: 7        85.27%
# ┃┃┃┃┃┏Current depth: 6        85.36%
# ┃┃┃┃┃┃┏Current depth: 7        85.45%
# ┃┃┃┃┃┃┏Current depth: 7        85.54%
# ┃┃┃┃┃┃┏Current depth: 7        85.64%
# ┃┃┃┃┃┏Current depth: 6        85.73%
# ┃┃┃┃┃┃┏Current depth: 7        85.82%
# ┃┃┃┃┃┃┏Current depth: 7        85.91%
# ┃┃┃┃┃┃┏Current depth: 7        86.00%
# ┃┃┃┃┃┏Current depth: 6        86.09%
# ┃┃┃┃┏Current depth: 5        86.18%
# ┃┃┃┃┃┃┏Current depth: 7        86.28%
# ┃┃┃┃┃┃┏Current depth: 7        86.37%
# ┃┃┃┃┃┃┏Current depth: 7        86.46%
# ┃┃┃┃┃┏Current depth: 6        86.55%
# ┃┃┃┃┃┃┏Current depth: 7        86.64%
# ┃┃┃┃┃┃┏Current depth: 7        86.73%
# ┃┃┃┃┃┃┏Current depth: 7        86.83%
# ┃┃┃┃┃┏Current depth: 6        86.92%
# ┃┃┃┃┃┃┏Current depth: 7        87.01%
# ┃┃┃┃┃┃┏Current depth: 7        87.10%
# ┃┃┃┃┃┃┏Current depth: 7        87.19%
# ┃┃┃┃┃┏Current depth: 6        87.28%
# ┃┃┃┃┏Current depth: 5        87.37%
# ┃┃┃┃┃┃┏Current depth: 7        87.47%
# ┃┃┃┃┃┃┏Current depth: 7        87.56%
# ┃┃┃┃┃┃┏Current depth: 7        87.65%
# ┃┃┃┃┃┏Current depth: 6        87.74%
# ┃┃┃┃┃┃┏Current depth: 7        87.83%
# ┃┃┃┃┃┃┏Current depth: 7        87.92%
# ┃┃┃┃┃┃┏Current depth: 7        88.01%
# ┃┃┃┃┃┏Current depth: 6        88.11%
# ┃┃┃┃┃┃┏Current depth: 7        88.20%
# ┃┃┃┃┃┃┏Current depth: 7        88.29%
# ┃┃┃┃┃┃┏Current depth: 7        88.38%
# ┃┃┃┃┃┏Current depth: 6        88.47%
# ┃┃┃┃┏Current depth: 5        88.56%
# ┃┃┃┏Current depth: 4        88.66%
# ┃┃┏Current depth: 3        88.75%
# ┃┃┃┃┃┃┏Current depth: 7        88.84%
# ┃┃┃┃┃┃┏Current depth: 7        88.93%
# ┃┃┃┃┃┃┏Current depth: 7        89.02%
# ┃┃┃┃┃┏Current depth: 6        89.11%
# ┃┃┃┃┃┃┏Current depth: 7        89.20%
# ┃┃┃┃┃┃┏Current depth: 7        89.30%
# ┃┃┃┃┃┃┏Current depth: 7        89.39%
# ┃┃┃┃┃┏Current depth: 6        89.48%
# ┃┃┃┃┃┃┏Current depth: 7        89.57%
# ┃┃┃┃┃┃┏Current depth: 7        89.66%
# ┃┃┃┃┃┃┏Current depth: 7        89.75%
# ┃┃┃┃┃┏Current depth: 6        89.84%
# ┃┃┃┃┏Current depth: 5        89.94%
# ┃┃┃┃┃┃┏Current depth: 7        90.03%
# ┃┃┃┃┃┃┏Current depth: 7        90.12%
# ┃┃┃┃┃┃┏Current depth: 7        90.21%
# ┃┃┃┃┃┏Current depth: 6        90.30%
# ┃┃┃┃┃┃┏Current depth: 7        90.39%
# ┃┃┃┃┃┃┏Current depth: 7        90.48%
# ┃┃┃┃┃┃┏Current depth: 7        90.58%
# ┃┃┃┃┃┏Current depth: 6        90.67%
# ┃┃┃┃┃┃┏Current depth: 7        90.76%
# ┃┃┃┃┃┃┏Current depth: 7        90.85%
# ┃┃┃┃┃┃┏Current depth: 7        90.94%
# ┃┃┃┃┃┏Current depth: 6        91.03%
# ┃┃┃┃┏Current depth: 5        91.13%
# ┃┃┃┃┃┃┏Current depth: 7        91.22%
# ┃┃┃┃┃┃┏Current depth: 7        91.31%
# ┃┃┃┃┃┃┏Current depth: 7        91.40%
# ┃┃┃┃┃┏Current depth: 6        91.49%
# ┃┃┃┃┃┃┏Current depth: 7        91.58%
# ┃┃┃┃┃┃┏Current depth: 7        91.67%
# ┃┃┃┃┃┃┏Current depth: 7        91.77%
# ┃┃┃┃┃┏Current depth: 6        91.86%
# ┃┃┃┃┃┃┏Current depth: 7        91.95%
# ┃┃┃┃┃┃┏Current depth: 7        92.04%
# ┃┃┃┃┃┃┏Current depth: 7        92.13%
# ┃┃┃┃┃┏Current depth: 6        92.22%
# ┃┃┃┃┏Current depth: 5        92.31%
# ┃┃┃┏Current depth: 4        92.41%
# ┃┃┃┃┃┃┏Current depth: 7        92.50%
# ┃┃┃┃┃┃┏Current depth: 7        92.59%
# ┃┃┃┃┃┃┏Current depth: 7        92.68%
# ┃┃┃┃┃┏Current depth: 6        92.77%
# ┃┃┃┃┃┃┏Current depth: 7        92.86%
# ┃┃┃┃┃┃┏Current depth: 7        92.96%
# ┃┃┃┃┃┃┏Current depth: 7        93.05%
# ┃┃┃┃┃┏Current depth: 6        93.14%
# ┃┃┃┃┃┃┏Current depth: 7        93.23%
# ┃┃┃┃┃┃┏Current depth: 7        93.32%
# ┃┃┃┃┃┃┏Current depth: 7        93.41%
# ┃┃┃┃┃┏Current depth: 6        93.50%
# ┃┃┃┃┏Current depth: 5        93.60%
# ┃┃┃┃┃┃┏Current depth: 7        93.69%
# ┃┃┃┃┃┃┏Current depth: 7        93.78%
# ┃┃┃┃┃┃┏Current depth: 7        93.87%
# ┃┃┃┃┃┏Current depth: 6        93.96%
# ┃┃┃┃┃┃┏Current depth: 7        94.05%
# ┃┃┃┃┃┃┏Current depth: 7        94.14%
# ┃┃┃┃┃┃┏Current depth: 7        94.24%
# ┃┃┃┃┃┏Current depth: 6        94.33%
# ┃┃┃┃┃┃┏Current depth: 7        94.42%
# ┃┃┃┃┃┃┏Current depth: 7        94.51%
# ┃┃┃┃┃┃┏Current depth: 7        94.60%
# ┃┃┃┃┃┏Current depth: 6        94.69%
# ┃┃┃┃┏Current depth: 5        94.78%
# ┃┃┃┃┃┃┏Current depth: 7        94.88%
# ┃┃┃┃┃┃┏Current depth: 7        94.97%
# ┃┃┃┃┃┃┏Current depth: 7        95.06%
# ┃┃┃┃┃┏Current depth: 6        95.15%
# ┃┃┃┃┃┃┏Current depth: 7        95.24%
# ┃┃┃┃┃┃┏Current depth: 7        95.33%
# ┃┃┃┃┃┃┏Current depth: 7        95.43%
# ┃┃┃┃┃┏Current depth: 6        95.52%
# ┃┃┃┃┃┃┏Current depth: 7        95.61%
# ┃┃┃┃┃┃┏Current depth: 7        95.70%
# ┃┃┃┃┃┃┏Current depth: 7        95.79%
# ┃┃┃┃┃┏Current depth: 6        95.88%
# ┃┃┃┃┏Current depth: 5        95.97%
# ┃┃┃┏Current depth: 4        96.07%
# ┃┃┃┃┃┃┏Current depth: 7        96.16%
# ┃┃┃┃┃┃┏Current depth: 7        96.25%
# ┃┃┃┃┃┃┏Current depth: 7        96.34%
# ┃┃┃┃┃┏Current depth: 6        96.43%
# ┃┃┃┃┃┃┏Current depth: 7        96.52%
# ┃┃┃┃┃┃┏Current depth: 7        96.61%
# ┃┃┃┃┃┃┏Current depth: 7        96.71%
# ┃┃┃┃┃┏Current depth: 6        96.80%
# ┃┃┃┃┃┃┏Current depth: 7        96.89%
# ┃┃┃┃┃┃┏Current depth: 7        96.98%
# ┃┃┃┃┃┃┏Current depth: 7        97.07%
# ┃┃┃┃┃┏Current depth: 6        97.16%
# ┃┃┃┃┏Current depth: 5        97.26%
# ┃┃┃┃┃┃┏Current depth: 7        97.35%
# ┃┃┃┃┃┃┏Current depth: 7        97.44%
# ┃┃┃┃┃┃┏Current depth: 7        97.53%
# ┃┃┃┃┃┏Current depth: 6        97.62%
# ┃┃┃┃┃┃┏Current depth: 7        97.71%
# ┃┃┃┃┃┃┏Current depth: 7        97.80%
# ┃┃┃┃┃┃┏Current depth: 7        97.90%
# ┃┃┃┃┃┏Current depth: 6        97.99%
# ┃┃┃┃┃┃┏Current depth: 7        98.08%
# ┃┃┃┃┃┃┏Current depth: 7        98.17%
# ┃┃┃┃┃┃┏Current depth: 7        98.26%
# ┃┃┃┃┃┏Current depth: 6        98.35%
# ┃┃┃┃┏Current depth: 5        98.44%
# ┃┃┃┃┃┃┏Current depth: 7        98.54%
# ┃┃┃┃┃┃┏Current depth: 7        98.63%
# ┃┃┃┃┃┃┏Current depth: 7        98.72%
# ┃┃┃┃┃┏Current depth: 6        98.81%
# ┃┃┃┃┃┃┏Current depth: 7        98.90%
# ┃┃┃┃┃┃┏Current depth: 7        98.99%
# ┃┃┃┃┃┃┏Current depth: 7        99.09%
# ┃┃┃┃┃┏Current depth: 6        99.18%
# ┃┃┃┃┃┃┏Current depth: 7        99.27%
# ┃┃┃┃┃┃┏Current depth: 7        99.36%
# ┃┃┃┃┃┃┏Current depth: 7        99.45%
# ┃┃┃┃┃┏Current depth: 6        99.54%
# ┃┃┃┃┏Current depth: 5        99.63%
# ┃┃┃┏Current depth: 4        99.73%
# ┃┃┏Current depth: 3        99.82%
# ┃┏Current depth: 2        99.91%
# ┏Current depth: 1        100.00%
# MF DONE
# MF DONE
# MF DONE
# MF DONE
# MF DONE
# MF DONE
# MF DONE
# MF DONE

# %% [markdown]
# ## Step 5: Calculate RMSE on test dataset

# %%
rmse_result = pred_RMSE_for_new_item(dtmodel_realdata, sM_testing)

# %%
rmse_result
# Out:
# 1.0401063646870545

# %% [markdown]
# ## Step 6: stop spark

# %%
dtmodel_realdata.MF.end()
